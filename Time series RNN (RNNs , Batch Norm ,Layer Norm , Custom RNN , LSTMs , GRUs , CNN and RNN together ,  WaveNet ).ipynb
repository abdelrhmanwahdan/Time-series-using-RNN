# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. LSTMs and CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os
from pathlib import Path

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# No GPU was detected. LSTMs and CNNs can be very slow without a GPU.

# %% [markdown]
# ## Generate the Dataset

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))
save_fig("time_series_plot")
plt.show()
# Out:
# Saving figure time_series_plot

# %% [markdown]
# ## Computing Some Baselines

# %% [markdown]
# Naive predictions (just predict the last observed value):

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.020211367

# %%
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# Linear predictions:

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1001 - val_loss: 0.0545
# Epoch 2/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0379 - val_loss: 0.0266
# Epoch 3/20
# 219/219 [==============================] - 0s 985us/step - loss: 0.0202 - val_loss: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0116
# Epoch 5/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 6/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 7/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 8/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 9/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 10/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 11/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 12/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 13/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 14/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 15/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 16/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 17/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 18/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 19/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 20/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0042

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 772us/step - loss: 0.0042
# 0.004168087150901556

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ## Using a Simple RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(lr=0.005)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0967 - val_loss: 0.0489
# Epoch 2/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0369 - val_loss: 0.0296
# Epoch 3/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0253 - val_loss: 0.0218
# Epoch 4/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0198 - val_loss: 0.0177
# Epoch 5/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0166 - val_loss: 0.0151
# Epoch 6/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0146 - val_loss: 0.0134
# Epoch 7/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 8/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0124 - val_loss: 0.0116
# Epoch 9/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0118 - val_loss: 0.0112
# Epoch 10/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0116 - val_loss: 0.0110
# Epoch 11/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0109
# 0.010881561785936356

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ## Deep RNNs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0492 - val_loss: 0.0090
# Epoch 2/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 3/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 4/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 5/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 6/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 7/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 8/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 9/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 10/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 11/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 12/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 13/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 14/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 15/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 16/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 17/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 18/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 19/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 20/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0032 - val_loss: 0.0029

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0029
# 0.002910564187914133

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# Make the second SimpleRNN layer return only the last output:

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0232 - val_loss: 0.0052
# Epoch 2/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 3/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 4/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 5/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 6/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 7/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 8/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 9/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 10/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 11/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 12/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 13/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 14/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 15/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 16/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 17/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 18/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 19/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 20/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0029 - val_loss: 0.0026

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0026
# 0.002623623004183173

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ## Forecasting Several Steps Ahead

# %%
np.random.seed(43) # not 42, as it would give the first series in the train set

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
Y_pred.shape
# Out:
# (1, 10, 1)

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
save_fig("forecast_ahead_plot")
plt.show()
# Out:
# Saving figure forecast_ahead_plot

# %% [markdown]
# Now let's use this model to predict the next 10 values. We first need to regenerate the sequences with 9 more time steps.

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %% [markdown]
# Now let's predict the next 10 values one by one:

# %%
X = X_valid
for step_ahead in range(10):
    y_pred_one = model.predict(X)[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:, 0]

# %%
Y_pred.shape
# Out:
# (2000, 10)

# %%
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_pred))
# Out:
# 0.027510857

# %% [markdown]
# Let's compare this performance with some baselines: naive predictions and a simple linear model:

# %%
Y_naive_pred = Y_valid[:, -1:]
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_naive_pred))
# Out:
# 0.22278848

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1343 - val_loss: 0.0606
# Epoch 2/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0496 - val_loss: 0.0425
# Epoch 3/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0385 - val_loss: 0.0353
# Epoch 4/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0331 - val_loss: 0.0311
# Epoch 5/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0283
# Epoch 6/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0273 - val_loss: 0.0264
# Epoch 7/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0256 - val_loss: 0.0249
# Epoch 8/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0244 - val_loss: 0.0237
# Epoch 9/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0234 - val_loss: 0.0229
# Epoch 10/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0227 - val_loss: 0.0222
# Epoch 11/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0220 - val_loss: 0.0216
# Epoch 12/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 13/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0210 - val_loss: 0.0208
# Epoch 14/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0207
# Epoch 15/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 16/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0199
# Epoch 17/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 18/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.0192
# Epoch 19/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 20/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0188 - val_loss: 0.0187

# %% [markdown]
# Now let's create an RNN that predicts all 10 next values at once:

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0669 - val_loss: 0.0317
# Epoch 2/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0265 - val_loss: 0.0200
# Epoch 3/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0183 - val_loss: 0.0160
# Epoch 4/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0155 - val_loss: 0.0144
# Epoch 5/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0139 - val_loss: 0.0118
# Epoch 6/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0112
# Epoch 7/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 8/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0115 - val_loss: 0.0103
# Epoch 9/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 10/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0110 - val_loss: 0.0100
# Epoch 11/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 12/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 13/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 14/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 15/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0095 - val_loss: 0.0107
# Epoch 16/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0092 - val_loss: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0094 - val_loss: 0.0111
# Epoch 18/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 19/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0093 - val_loss: 0.0083
# Epoch 20/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0094 - val_loss: 0.0085

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# Now let's create an RNN that predicts the next 10 steps at each time step. That is, instead of just forecasting time steps 50 to 59 based on time steps 0 to 49, it will forecast time steps 1 to 10 at time step 0, then time steps 2 to 11 at time step 1, and so on, and finally it will forecast time steps 50 to 59 at the last time step. Notice that the model is causal: when it makes predictions at any time step, it can only see past time steps.

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
X_train.shape, Y_train.shape
# Out:
# ((7000, 50, 1), (7000, 50, 10))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer=keras.optimizers.Adam(lr=0.01), metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0508 - last_time_step_mse: 0.0400 - val_loss: 0.0429 - val_last_time_step_mse: 0.0324
# Epoch 2/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0395 - last_time_step_mse: 0.0283 - val_loss: 0.0367 - val_last_time_step_mse: 0.0267
# Epoch 3/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0326 - last_time_step_mse: 0.0214 - val_loss: 0.0308 - val_last_time_step_mse: 0.0186
# Epoch 4/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0297 - last_time_step_mse: 0.0186 - val_loss: 0.0279 - val_last_time_step_mse: 0.0159
# Epoch 5/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0272 - last_time_step_mse: 0.0152 - val_loss: 0.0268 - val_last_time_step_mse: 0.0167
# Epoch 6/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0252 - last_time_step_mse: 0.0125 - val_loss: 0.0219 - val_last_time_step_mse: 0.0085
# Epoch 7/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0232 - last_time_step_mse: 0.0104 - val_loss: 0.0232 - val_last_time_step_mse: 0.0102
# Epoch 8/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0217 - last_time_step_mse: 0.0088 - val_loss: 0.0217 - val_last_time_step_mse: 0.0093
# Epoch 9/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0213 - last_time_step_mse: 0.0085 - val_loss: 0.0204 - val_last_time_step_mse: 0.0076
# Epoch 10/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0211 - last_time_step_mse: 0.0086 - val_loss: 0.0202 - val_last_time_step_mse: 0.0073
# Epoch 11/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0205 - last_time_step_mse: 0.0081 - val_loss: 0.0197 - val_last_time_step_mse: 0.0072
# Epoch 12/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0202 - last_time_step_mse: 0.0080 - val_loss: 0.0202 - val_last_time_step_mse: 0.0085
# Epoch 13/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0198 - last_time_step_mse: 0.0075 - val_loss: 0.0209 - val_last_time_step_mse: 0.0083
# Epoch 14/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0192 - last_time_step_mse: 0.0071 - val_loss: 0.0191 - val_last_time_step_mse: 0.0068
# Epoch 15/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0192 - last_time_step_mse: 0.0071 - val_loss: 0.0183 - val_last_time_step_mse: 0.0069
# Epoch 16/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0189 - last_time_step_mse: 0.0068 - val_loss: 0.0190 - val_last_time_step_mse: 0.0083
# Epoch 17/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0187 - last_time_step_mse: 0.0067 - val_loss: 0.0183 - val_last_time_step_mse: 0.0069
# Epoch 18/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0188 - last_time_step_mse: 0.0072 - val_loss: 0.0178 - val_last_time_step_mse: 0.0063
# Epoch 19/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0185 - last_time_step_mse: 0.0069 - val_loss: 0.0173 - val_last_time_step_mse: 0.0058
# Epoch 20/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0185 - last_time_step_mse: 0.0069 - val_loss: 0.0197 - val_last_time_step_mse: 0.0086

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# ## Deep RNN with Batch Norm

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.BatchNormalization(),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.BatchNormalization(),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.1929 - last_time_step_mse: 0.1902 - val_loss: 0.0877 - val_last_time_step_mse: 0.0832
# Epoch 2/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0537 - last_time_step_mse: 0.0449 - val_loss: 0.0549 - val_last_time_step_mse: 0.0462
# Epoch 3/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0471 - last_time_step_mse: 0.0375 - val_loss: 0.0451 - val_last_time_step_mse: 0.0358
# Epoch 4/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0437 - last_time_step_mse: 0.0337 - val_loss: 0.0418 - val_last_time_step_mse: 0.0314
# Epoch 5/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0409 - last_time_step_mse: 0.0306 - val_loss: 0.0391 - val_last_time_step_mse: 0.0287
# Epoch 6/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0385 - last_time_step_mse: 0.0275 - val_loss: 0.0379 - val_last_time_step_mse: 0.0273
# Epoch 7/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0366 - last_time_step_mse: 0.0254 - val_loss: 0.0367 - val_last_time_step_mse: 0.0248
# Epoch 8/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0349 - last_time_step_mse: 0.0235 - val_loss: 0.0363 - val_last_time_step_mse: 0.0249
# Epoch 9/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0338 - last_time_step_mse: 0.0221 - val_loss: 0.0332 - val_last_time_step_mse: 0.0208
# Epoch 10/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0329 - last_time_step_mse: 0.0214 - val_loss: 0.0335 - val_last_time_step_mse: 0.0214
# Epoch 11/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0322 - last_time_step_mse: 0.0206 - val_loss: 0.0323 - val_last_time_step_mse: 0.0203
# Epoch 12/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0316 - last_time_step_mse: 0.0198 - val_loss: 0.0333 - val_last_time_step_mse: 0.0210
# Epoch 13/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0310 - last_time_step_mse: 0.0191 - val_loss: 0.0310 - val_last_time_step_mse: 0.0187
# Epoch 14/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0305 - last_time_step_mse: 0.0186 - val_loss: 0.0310 - val_last_time_step_mse: 0.0189
# Epoch 15/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0302 - last_time_step_mse: 0.0182 - val_loss: 0.0298 - val_last_time_step_mse: 0.0178
# Epoch 16/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0296 - last_time_step_mse: 0.0176 - val_loss: 0.0293 - val_last_time_step_mse: 0.0174
# Epoch 17/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0293 - last_time_step_mse: 0.0172 - val_loss: 0.0315 - val_last_time_step_mse: 0.0200
# Epoch 18/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0289 - last_time_step_mse: 0.0168 - val_loss: 0.0295 - val_last_time_step_mse: 0.0174
# Epoch 19/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0286 - last_time_step_mse: 0.0168 - val_loss: 0.0290 - val_last_time_step_mse: 0.0163
# Epoch 20/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0281 - last_time_step_mse: 0.0161 - val_loss: 0.0288 - val_last_time_step_mse: 0.0164

# %% [markdown]
# ## Deep RNNs with Layer Norm

# %%
from tensorflow.keras.layers import LayerNormalization

# %%
class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,
                                                          activation=None)
        self.layer_norm = LayerNormalization()
        self.activation = keras.activations.get(activation)
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        if inputs is not None:
            batch_size = tf.shape(inputs)[0]
            dtype = inputs.dtype
        return [tf.zeros([batch_size, self.state_size], dtype=dtype)]
    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True,
                     input_shape=[None, 1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 7s 32ms/step - loss: 0.1611 - last_time_step_mse: 0.1572 - val_loss: 0.0747 - val_last_time_step_mse: 0.0684
# Epoch 2/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0662 - last_time_step_mse: 0.0573 - val_loss: 0.0596 - val_last_time_step_mse: 0.0486
# Epoch 3/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0564 - last_time_step_mse: 0.0460 - val_loss: 0.0531 - val_last_time_step_mse: 0.0417
# Epoch 4/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0508 - last_time_step_mse: 0.0396 - val_loss: 0.0474 - val_last_time_step_mse: 0.0354
# Epoch 5/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0456 - last_time_step_mse: 0.0336 - val_loss: 0.0431 - val_last_time_step_mse: 0.0307
# Epoch 6/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0412 - last_time_step_mse: 0.0283 - val_loss: 0.0382 - val_last_time_step_mse: 0.0247
# Epoch 7/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0376 - last_time_step_mse: 0.0250 - val_loss: 0.0358 - val_last_time_step_mse: 0.0221
# Epoch 8/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0349 - last_time_step_mse: 0.0220 - val_loss: 0.0338 - val_last_time_step_mse: 0.0210
# Epoch 9/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0333 - last_time_step_mse: 0.0206 - val_loss: 0.0322 - val_last_time_step_mse: 0.0186
# Epoch 10/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0317 - last_time_step_mse: 0.0188 - val_loss: 0.0307 - val_last_time_step_mse: 0.0167
# Epoch 11/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0307 - last_time_step_mse: 0.0180 - val_loss: 0.0300 - val_last_time_step_mse: 0.0168
# Epoch 12/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0300 - last_time_step_mse: 0.0175 - val_loss: 0.0296 - val_last_time_step_mse: 0.0167
# Epoch 13/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0289 - last_time_step_mse: 0.0162 - val_loss: 0.0285 - val_last_time_step_mse: 0.0151
# Epoch 14/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0285 - last_time_step_mse: 0.0160 - val_loss: 0.0277 - val_last_time_step_mse: 0.0152
# Epoch 15/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0279 - last_time_step_mse: 0.0154 - val_loss: 0.0274 - val_last_time_step_mse: 0.0144
# Epoch 16/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0277 - last_time_step_mse: 0.0154 - val_loss: 0.0273 - val_last_time_step_mse: 0.0142
# Epoch 17/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0270 - last_time_step_mse: 0.0146 - val_loss: 0.0267 - val_last_time_step_mse: 0.0142
# Epoch 18/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0267 - last_time_step_mse: 0.0142 - val_loss: 0.0262 - val_last_time_step_mse: 0.0137
# Epoch 19/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0264 - last_time_step_mse: 0.0140 - val_loss: 0.0261 - val_last_time_step_mse: 0.0129
# Epoch 20/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0261 - last_time_step_mse: 0.0136 - val_loss: 0.0256 - val_last_time_step_mse: 0.0128

# %% [markdown]
# ## Creating a Custom RNN Class¶

# %%
class MyRNN(keras.layers.Layer):
    def __init__(self, cell, return_sequences=False, **kwargs):
        super().__init__(**kwargs)
        self.cell = cell
        self.return_sequences = return_sequences
        self.get_initial_state = getattr(
            self.cell, "get_initial_state", self.fallback_initial_state)
    def fallback_initial_state(self, inputs):
        return [tf.zeros([self.cell.state_size], dtype=inputs.dtype)]
    @tf.function
    def call(self, inputs):
        states = self.get_initial_state(inputs)
        n_steps = tf.shape(inputs)[1]
        if self.return_sequences:
            sequences = tf.TensorArray(inputs.dtype, size=n_steps)
        outputs = tf.zeros(shape=[n_steps, self.cell.output_size], dtype=inputs.dtype)
        for step in tf.range(n_steps):
            outputs, states = self.cell(inputs[:, step], states)
            if self.return_sequences:
                sequences = sequences.write(step, outputs)
        if self.return_sequences:
            return sequences.stack()
        else:
            return outputs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    MyRNN(LNSimpleRNNCell(20), return_sequences=True,
          input_shape=[None, 1]),
    MyRNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 6s 28ms/step - loss: 0.1968 - last_time_step_mse: 0.1934 - val_loss: 0.0776 - val_last_time_step_mse: 0.0731
# Epoch 2/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0698 - last_time_step_mse: 0.0635 - val_loss: 0.0640 - val_last_time_step_mse: 0.0576
# Epoch 3/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0603 - last_time_step_mse: 0.0529 - val_loss: 0.0562 - val_last_time_step_mse: 0.0476
# Epoch 4/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0520 - last_time_step_mse: 0.0415 - val_loss: 0.0482 - val_last_time_step_mse: 0.0366
# Epoch 5/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0460 - last_time_step_mse: 0.0343 - val_loss: 0.0439 - val_last_time_step_mse: 0.0324
# Epoch 6/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0420 - last_time_step_mse: 0.0299 - val_loss: 0.0399 - val_last_time_step_mse: 0.0273
# Epoch 7/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0385 - last_time_step_mse: 0.0255 - val_loss: 0.0364 - val_last_time_step_mse: 0.0228
# Epoch 8/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0360 - last_time_step_mse: 0.0224 - val_loss: 0.0347 - val_last_time_step_mse: 0.0210
# Epoch 9/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0342 - last_time_step_mse: 0.0206 - val_loss: 0.0355 - val_last_time_step_mse: 0.0229
# Epoch 10/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0327 - last_time_step_mse: 0.0191 - val_loss: 0.0317 - val_last_time_step_mse: 0.0177
# Epoch 11/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0315 - last_time_step_mse: 0.0181 - val_loss: 0.0305 - val_last_time_step_mse: 0.0169
# Epoch 12/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0306 - last_time_step_mse: 0.0174 - val_loss: 0.0310 - val_last_time_step_mse: 0.0190
# Epoch 13/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0296 - last_time_step_mse: 0.0163 - val_loss: 0.0289 - val_last_time_step_mse: 0.0161
# Epoch 14/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0288 - last_time_step_mse: 0.0157 - val_loss: 0.0283 - val_last_time_step_mse: 0.0153
# Epoch 15/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0285 - last_time_step_mse: 0.0155 - val_loss: 0.0280 - val_last_time_step_mse: 0.0149
# Epoch 16/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0280 - last_time_step_mse: 0.0151 - val_loss: 0.0277 - val_last_time_step_mse: 0.0148
# Epoch 17/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0275 - last_time_step_mse: 0.0146 - val_loss: 0.0271 - val_last_time_step_mse: 0.0139
# Epoch 18/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0271 - last_time_step_mse: 0.0142 - val_loss: 0.0269 - val_last_time_step_mse: 0.0142
# Epoch 19/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0267 - last_time_step_mse: 0.0139 - val_loss: 0.0265 - val_last_time_step_mse: 0.0135
# Epoch 20/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0263 - last_time_step_mse: 0.0134 - val_loss: 0.0266 - val_last_time_step_mse: 0.0143

# %% [markdown]
# ## LSTMs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0760 - last_time_step_mse: 0.0615 - val_loss: 0.0554 - val_last_time_step_mse: 0.0364
# Epoch 2/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0480 - last_time_step_mse: 0.0283 - val_loss: 0.0427 - val_last_time_step_mse: 0.0222
# Epoch 3/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0391 - last_time_step_mse: 0.0181 - val_loss: 0.0367 - val_last_time_step_mse: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 6s 28ms/step - loss: 0.0350 - last_time_step_mse: 0.0151 - val_loss: 0.0334 - val_last_time_step_mse: 0.0132
# Epoch 5/20
# 219/219 [==============================] - 6s 28ms/step - loss: 0.0325 - last_time_step_mse: 0.0133 - val_loss: 0.0314 - val_last_time_step_mse: 0.0121
# Epoch 6/20
# 219/219 [==============================] - 6s 28ms/step - loss: 0.0308 - last_time_step_mse: 0.0122 - val_loss: 0.0298 - val_last_time_step_mse: 0.0112
# Epoch 7/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0297 - last_time_step_mse: 0.0118 - val_loss: 0.0291 - val_last_time_step_mse: 0.0120
# Epoch 8/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0286 - last_time_step_mse: 0.0109 - val_loss: 0.0278 - val_last_time_step_mse: 0.0099
# Epoch 9/20
# 219/219 [==============================] - 6s 30ms/step - loss: 0.0280 - last_time_step_mse: 0.0108 - val_loss: 0.0278 - val_last_time_step_mse: 0.0113
# Epoch 10/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0273 - last_time_step_mse: 0.0105 - val_loss: 0.0268 - val_last_time_step_mse: 0.0101
# Epoch 11/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0269 - last_time_step_mse: 0.0102 - val_loss: 0.0263 - val_last_time_step_mse: 0.0096
# Epoch 12/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0264 - last_time_step_mse: 0.0101 - val_loss: 0.0263 - val_last_time_step_mse: 0.0105
# Epoch 13/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0259 - last_time_step_mse: 0.0097 - val_loss: 0.0257 - val_last_time_step_mse: 0.0100
# Epoch 14/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0257 - last_time_step_mse: 0.0096 - val_loss: 0.0252 - val_last_time_step_mse: 0.0091
# Epoch 15/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0253 - last_time_step_mse: 0.0095 - val_loss: 0.0251 - val_last_time_step_mse: 0.0092
# Epoch 16/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0251 - last_time_step_mse: 0.0095 - val_loss: 0.0248 - val_last_time_step_mse: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0248 - last_time_step_mse: 0.0094 - val_loss: 0.0248 - val_last_time_step_mse: 0.0098
# Epoch 18/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0245 - last_time_step_mse: 0.0093 - val_loss: 0.0246 - val_last_time_step_mse: 0.0091
# Epoch 19/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0242 - last_time_step_mse: 0.0091 - val_loss: 0.0238 - val_last_time_step_mse: 0.0085
# Epoch 20/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0239 - last_time_step_mse: 0.0089 - val_loss: 0.0238 - val_last_time_step_mse: 0.0086

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0238 - last_time_step_mse: 0.0086
# [0.023788683116436005, 0.008560800924897194]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# ## GRUs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0738 - last_time_step_mse: 0.0655 - val_loss: 0.0538 - val_last_time_step_mse: 0.0450
# Epoch 2/20
# 219/219 [==============================] - 7s 33ms/step - loss: 0.0476 - last_time_step_mse: 0.0367 - val_loss: 0.0441 - val_last_time_step_mse: 0.0326
# Epoch 3/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0417 - last_time_step_mse: 0.0301 - val_loss: 0.0390 - val_last_time_step_mse: 0.0275
# Epoch 4/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0368 - last_time_step_mse: 0.0243 - val_loss: 0.0339 - val_last_time_step_mse: 0.0202
# Epoch 5/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0326 - last_time_step_mse: 0.0180 - val_loss: 0.0312 - val_last_time_step_mse: 0.0164
# Epoch 6/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0306 - last_time_step_mse: 0.0155 - val_loss: 0.0294 - val_last_time_step_mse: 0.0143
# Epoch 7/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0295 - last_time_step_mse: 0.0145 - val_loss: 0.0300 - val_last_time_step_mse: 0.0162
# Epoch 8/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0283 - last_time_step_mse: 0.0135 - val_loss: 0.0278 - val_last_time_step_mse: 0.0130
# Epoch 9/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0276 - last_time_step_mse: 0.0130 - val_loss: 0.0273 - val_last_time_step_mse: 0.0127
# Epoch 10/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0269 - last_time_step_mse: 0.0125 - val_loss: 0.0264 - val_last_time_step_mse: 0.0121
# Epoch 11/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0265 - last_time_step_mse: 0.0121 - val_loss: 0.0268 - val_last_time_step_mse: 0.0135
# Epoch 12/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0263 - last_time_step_mse: 0.0123 - val_loss: 0.0261 - val_last_time_step_mse: 0.0123
# Epoch 13/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0258 - last_time_step_mse: 0.0116 - val_loss: 0.0254 - val_last_time_step_mse: 0.0116
# Epoch 14/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0256 - last_time_step_mse: 0.0117 - val_loss: 0.0254 - val_last_time_step_mse: 0.0116
# Epoch 15/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0253 - last_time_step_mse: 0.0114 - val_loss: 0.0250 - val_last_time_step_mse: 0.0112
# Epoch 16/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0251 - last_time_step_mse: 0.0114 - val_loss: 0.0250 - val_last_time_step_mse: 0.0114
# Epoch 17/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0248 - last_time_step_mse: 0.0112 - val_loss: 0.0249 - val_last_time_step_mse: 0.0118
# Epoch 18/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0245 - last_time_step_mse: 0.0110 - val_loss: 0.0244 - val_last_time_step_mse: 0.0108
# Epoch 19/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0243 - last_time_step_mse: 0.0108 - val_loss: 0.0240 - val_last_time_step_mse: 0.0105
# Epoch 20/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0240 - last_time_step_mse: 0.0106 - val_loss: 0.0238 - val_last_time_step_mse: 0.0103

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0238 - last_time_step_mse: 0.0103
# [0.023785505443811417, 0.010262805968523026]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# ## Using One-Dimensional Convolutional Layers to Process Sequences

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train[:, 3::2], epochs=20,
                    validation_data=(X_valid, Y_valid[:, 3::2]))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0681 - last_time_step_mse: 0.0601 - val_loss: 0.0477 - val_last_time_step_mse: 0.0396
# Epoch 2/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0414 - last_time_step_mse: 0.0340 - val_loss: 0.0367 - val_last_time_step_mse: 0.0285
# Epoch 3/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0338 - last_time_step_mse: 0.0257 - val_loss: 0.0307 - val_last_time_step_mse: 0.0218
# Epoch 4/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0282 - last_time_step_mse: 0.0184 - val_loss: 0.0259 - val_last_time_step_mse: 0.0152
# Epoch 5/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0249 - last_time_step_mse: 0.0143 - val_loss: 0.0246 - val_last_time_step_mse: 0.0141
# Epoch 6/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0234 - last_time_step_mse: 0.0125 - val_loss: 0.0227 - val_last_time_step_mse: 0.0115
# Epoch 7/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0226 - last_time_step_mse: 0.0117 - val_loss: 0.0225 - val_last_time_step_mse: 0.0116
# Epoch 8/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0220 - last_time_step_mse: 0.0111 - val_loss: 0.0216 - val_last_time_step_mse: 0.0105
# Epoch 9/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0216 - last_time_step_mse: 0.0108 - val_loss: 0.0217 - val_last_time_step_mse: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0213 - last_time_step_mse: 0.0106 - val_loss: 0.0210 - val_last_time_step_mse: 0.0102
# Epoch 11/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0210 - last_time_step_mse: 0.0102 - val_loss: 0.0208 - val_last_time_step_mse: 0.0100
# Epoch 12/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0208 - last_time_step_mse: 0.0102 - val_loss: 0.0208 - val_last_time_step_mse: 0.0102
# Epoch 13/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0205 - last_time_step_mse: 0.0098 - val_loss: 0.0206 - val_last_time_step_mse: 0.0101
# Epoch 14/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0204 - last_time_step_mse: 0.0099 - val_loss: 0.0204 - val_last_time_step_mse: 0.0099
# Epoch 15/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0202 - last_time_step_mse: 0.0097 - val_loss: 0.0199 - val_last_time_step_mse: 0.0093
# Epoch 16/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0200 - last_time_step_mse: 0.0097 - val_loss: 0.0201 - val_last_time_step_mse: 0.0095
# Epoch 17/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0196 - last_time_step_mse: 0.0093 - val_loss: 0.0197 - val_last_time_step_mse: 0.0091
# Epoch 18/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0194 - last_time_step_mse: 0.0090 - val_loss: 0.0192 - val_last_time_step_mse: 0.0086
# Epoch 19/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0190 - last_time_step_mse: 0.0087 - val_loss: 0.0188 - val_last_time_step_mse: 0.0084
# Epoch 20/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0186 - last_time_step_mse: 0.0083 - val_loss: 0.0184 - val_last_time_step_mse: 0.0080

# %% [markdown]
# ## WaveNet

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0669 - last_time_step_mse: 0.0543 - val_loss: 0.0365 - val_last_time_step_mse: 0.0231
# Epoch 2/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0324 - last_time_step_mse: 0.0193 - val_loss: 0.0294 - val_last_time_step_mse: 0.0166
# Epoch 3/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0283 - last_time_step_mse: 0.0156 - val_loss: 0.0269 - val_last_time_step_mse: 0.0145
# Epoch 4/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0261 - last_time_step_mse: 0.0136 - val_loss: 0.0254 - val_last_time_step_mse: 0.0130
# Epoch 5/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0248 - last_time_step_mse: 0.0124 - val_loss: 0.0244 - val_last_time_step_mse: 0.0122
# Epoch 6/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0240 - last_time_step_mse: 0.0117 - val_loss: 0.0233 - val_last_time_step_mse: 0.0108
# Epoch 7/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0234 - last_time_step_mse: 0.0112 - val_loss: 0.0230 - val_last_time_step_mse: 0.0109
# Epoch 8/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0227 - last_time_step_mse: 0.0106 - val_loss: 0.0228 - val_last_time_step_mse: 0.0105
# Epoch 9/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0223 - last_time_step_mse: 0.0102 - val_loss: 0.0225 - val_last_time_step_mse: 0.0107
# Epoch 10/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0220 - last_time_step_mse: 0.0101 - val_loss: 0.0214 - val_last_time_step_mse: 0.0092
# Epoch 11/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0214 - last_time_step_mse: 0.0094 - val_loss: 0.0211 - val_last_time_step_mse: 0.0091
# Epoch 12/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0211 - last_time_step_mse: 0.0091 - val_loss: 0.0214 - val_last_time_step_mse: 0.0099
# Epoch 13/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0208 - last_time_step_mse: 0.0089 - val_loss: 0.0204 - val_last_time_step_mse: 0.0084
# Epoch 14/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0204 - last_time_step_mse: 0.0086 - val_loss: 0.0202 - val_last_time_step_mse: 0.0084
# Epoch 15/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0202 - last_time_step_mse: 0.0083 - val_loss: 0.0198 - val_last_time_step_mse: 0.0079
# Epoch 16/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0200 - last_time_step_mse: 0.0083 - val_loss: 0.0197 - val_last_time_step_mse: 0.0080
# Epoch 17/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0197 - last_time_step_mse: 0.0079 - val_loss: 0.0194 - val_last_time_step_mse: 0.0077
# Epoch 18/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0194 - last_time_step_mse: 0.0075 - val_loss: 0.0192 - val_last_time_step_mse: 0.0076
# Epoch 19/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0193 - last_time_step_mse: 0.0075 - val_loss: 0.0188 - val_last_time_step_mse: 0.0072
# Epoch 20/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0191 - last_time_step_mse: 0.0074 - val_loss: 0.0188 - val_last_time_step_mse: 0.0072

# %%
class GatedActivationUnit(keras.layers.Layer):
    def __init__(self, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
    def call(self, inputs):
        n_filters = inputs.shape[-1] // 2
        linear_output = self.activation(inputs[..., :n_filters])
        gate = keras.activations.sigmoid(inputs[..., n_filters:])
        return self.activation(linear_output) * gate

# %%
def wavenet_residual_block(inputs, n_filters, dilation_rate):
    z = keras.layers.Conv1D(2 * n_filters, kernel_size=2, padding="causal",
                            dilation_rate=dilation_rate)(inputs)
    z = GatedActivationUnit()(z)
    z = keras.layers.Conv1D(n_filters, kernel_size=1)(z)
    return keras.layers.Add()([z, inputs]), z

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

n_layers_per_block = 3 # 10 in the paper
n_blocks = 1 # 3 in the paper
n_filters = 32 # 128 in the paper
n_outputs = 10 # 256 in the paper

inputs = keras.layers.Input(shape=[None, 1])
z = keras.layers.Conv1D(n_filters, kernel_size=2, padding="causal")(inputs)
skip_to_last = []
for dilation_rate in [2**i for i in range(n_layers_per_block)] * n_blocks:
    z, skip = wavenet_residual_block(z, n_filters, dilation_rate)
    skip_to_last.append(skip)
z = keras.activations.relu(keras.layers.Add()(skip_to_last))
z = keras.layers.Conv1D(n_filters, kernel_size=1, activation="relu")(z)
Y_proba = keras.layers.Conv1D(n_outputs, kernel_size=1, activation="softmax")(z)

model = keras.models.Model(inputs=[inputs], outputs=[Y_proba])

# %%
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.1300 - last_time_step_mse: 0.1260 - val_loss: 0.1229 - val_last_time_step_mse: 0.1199
# Epoch 2/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.1222 - last_time_step_mse: 0.1178 - val_loss: 0.1217 - val_last_time_step_mse: 0.1189
# Epoch 3/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.1215 - last_time_step_mse: 0.1172 - val_loss: 0.1214 - val_last_time_step_mse: 0.1186
# Epoch 4/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.1212 - last_time_step_mse: 0.1169 - val_loss: 0.1211 - val_last_time_step_mse: 0.1183
# Epoch 5/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1210 - last_time_step_mse: 0.1167 - val_loss: 0.1209 - val_last_time_step_mse: 0.1181
# Epoch 6/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1209 - last_time_step_mse: 0.1165 - val_loss: 0.1208 - val_last_time_step_mse: 0.1179
# Epoch 7/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.1208 - last_time_step_mse: 0.1165 - val_loss: 0.1207 - val_last_time_step_mse: 0.1178
# Epoch 8/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.1206 - last_time_step_mse: 0.1164 - val_loss: 0.1206 - val_last_time_step_mse: 0.1178
# Epoch 9/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.1205 - last_time_step_mse: 0.1162 - val_loss: 0.1205 - val_last_time_step_mse: 0.1177
# Epoch 10/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1204 - last_time_step_mse: 0.1162 - val_loss: 0.1205 - val_last_time_step_mse: 0.1178
# Epoch 11/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.1204 - last_time_step_mse: 0.1161 - val_loss: 0.1204 - val_last_time_step_mse: 0.1176
# Epoch 12/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1203 - last_time_step_mse: 0.1160 - val_loss: 0.1202 - val_last_time_step_mse: 0.1174
# Epoch 13/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1202 - last_time_step_mse: 0.1159 - val_loss: 0.1202 - val_last_time_step_mse: 0.1174
# Epoch 14/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1201 - last_time_step_mse: 0.1159 - val_loss: 0.1202 - val_last_time_step_mse: 0.1174
# Epoch 15/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1201 - last_time_step_mse: 0.1157 - val_loss: 0.1201 - val_last_time_step_mse: 0.1173
# Epoch 16/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.1200 - last_time_step_mse: 0.1157 - val_loss: 0.1202 - val_last_time_step_mse: 0.1175
# Epoch 17/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1200 - last_time_step_mse: 0.1157 - val_loss: 0.1200 - val_last_time_step_mse: 0.1172
# Epoch 18/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1200 - last_time_step_mse: 0.1156 - val_loss: 0.1199 - val_last_time_step_mse: 0.1172
# Epoch 19/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1199 - last_time_step_mse: 0.1156 - val_loss: 0.1200 - val_last_time_step_mse: 0.1172
# Epoch 20/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1199 - last_time_step_mse: 0.1156 - val_loss: 0.1199 - val_last_time_step_mse: 0.1171
